# %%
# For analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
#For Modelling
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
import warnings

# %%
#import Dataset
df=pd.read_csv("StudentsData.csv")
df
# Out:
#      Student_ID  Gender Ethnicity Parental_Level_of_Education         Lunch  \
# 0             1    Male   Group D                 Associate's      Standard
# 1             2    Male   Group C                 High School      Standard
# 2             3  Female   Group D                    Master's  Free/Reduced
# 3             4    Male   Group C                    Master's  Free/Reduced
# 4             5  Female   Group D                    Master's      Standard
# ..          ...     ...       ...                         ...           ...
# 995         996  Female   Group A                    Master's      Standard
# 996         997    Male   Group D                  Bachelor's  Free/Reduced
# 997         998    Male   Group E                 High School      Standard
# 998         999    Male   Group E                  Bachelor's      Standard
# 999        1000  Female   Group A                    Master's  Free/Reduced
#
# ...

# %%
#Top 5 Entries
df.head()
# Out:
#    Student_ID  Gender Ethnicity Parental_Level_of_Education         Lunch  \
# 0           1    Male   Group D                 Associate's      Standard
# 1           2    Male   Group C                 High School      Standard
# 2           3  Female   Group D                    Master's  Free/Reduced
# 3           4    Male   Group C                    Master's  Free/Reduced
# 4           5  Female   Group D                    Master's      Standard
#
#   Test_Preparation_Course  Unnamed: 6  Unnamed: 7  Math_ score  Unnamed: 9  \
# 0               Completed         NaN         NaN           92         NaN
# 1               Completed         NaN         NaN           97         NaN
# 2                     NaN         NaN         NaN           62         NaN
# 3               Completed         NaN         NaN           64         NaN
# 4               Completed         NaN         NaN           74         NaN
#
#    Read_score  Unnamed: 11  Write_score
# ...

# %%
#Last 5 Entries
df.tail()
# Out:
#      Student_ID  Gender Ethnicity Parental_Level_of_Education         Lunch  \
# 995         996  Female   Group A                    Master's      Standard
# 996         997    Male   Group D                  Bachelor's  Free/Reduced
# 997         998    Male   Group E                 High School      Standard
# 998         999    Male   Group E                  Bachelor's      Standard
# 999        1000  Female   Group A                    Master's  Free/Reduced
#
#     Test_Preparation_Course  Unnamed: 6  Unnamed: 7  Math_ score  Unnamed: 9  \
# 995                     NaN         NaN         NaN           70         NaN
# 996                     NaN         NaN         NaN           90         NaN
# 997                     NaN         NaN         NaN           68         NaN
# 998                     NaN         NaN         NaN           68         NaN
# 999               Completed         NaN         NaN           78         NaN
#
#      Read_score  Unnamed: 11  Write_score
# ...

# %%
#Remove Particular Column
x=df.drop(columns=["Math_ score"],axis=1)
print(x)
# Out:
#      Student_ID  Gender Ethnicity Parental_Level_of_Education         Lunch  \
# 0             1    Male   Group D                 Associate's      Standard
# 1             2    Male   Group C                 High School      Standard
# 2             3  Female   Group D                    Master's  Free/Reduced
# 3             4    Male   Group C                    Master's  Free/Reduced
# 4             5  Female   Group D                    Master's      Standard
# ..          ...     ...       ...                         ...           ...
# 995         996  Female   Group A                    Master's      Standard
# 996         997    Male   Group D                  Bachelor's  Free/Reduced
# 997         998    Male   Group E                 High School      Standard
# 998         999    Male   Group E                  Bachelor's      Standard
# 999        1000  Female   Group A                    Master's  Free/Reduced
#
# ...

# %%
#select Particular Column with Index
x=df["Math_ score"]
print(x)
# Out:
# 0      92
# 1      97
# 2      62
# 3      64
# 4      74
#        ..
# 995    70
# 996    90
# 997    68
# 998    68
# 999    78
# Name: Math_ score, Length: 1000, dtype: int64

# %%
#DataTypes in Data Set
df.dtypes
# Out:
# Student_ID                       int64
# Gender                          object
# Ethnicity                       object
# Parental_Level_of_Education     object
# Lunch                           object
# Test_Preparation_Course         object
# Unnamed: 6                     float64
# Unnamed: 7                     float64
# Math_ score                      int64
# Unnamed: 9                     float64
# Read_score                       int64
# Unnamed: 11                    float64
# Write_score                      int64
# dtype: object

# %%
#Take an unique values from any Columns
print("Categories in 'Gender' Variable:",end=" ")
print(df['Gender'].unique())
print("Categories in 'Ethnicity' Variable:",end=" ")
print(df['Ethnicity'].unique())
print("Categories in 'Test_Preparation_Course' Variable:",end=" ")
print(df['Test_Preparation_Course'].unique())
print("Categories in 'Parental_Level_of_Education' Variable:",end=" ")
print(df['Parental_Level_of_Education'].unique())
print("Categories in 'Lunch' Variable:", end=" ")
print(df['Lunch'].unique())
print("Categories in 'Write_score' Variable:", end=" ")
print(df['Write_score'].unique())
# Out:
# Categories in 'Gender' Variable: ['Male' 'Female']
# Categories in 'Ethnicity' Variable: ['Group D' 'Group C' 'Group A' 'Group E' 'Group B']
# Categories in 'Test_Preparation_Course' Variable: ['Completed' nan]
# Categories in 'Parental_Level_of_Education' Variable: ["Associate's" 'High School' "Master's" "Bachelor's" 'Some College']
# Categories in 'Lunch' Variable: ['Standard' 'Free/Reduced']
# Categories in 'Write_score' Variable: [ 70  64  53  79  98  60  77  55  63  82  89  73  85  71  80  74  75  78
#   66  88  67  54  51  65  86  61  50  90  92  84  95  81  58  76  68  93
#   52  87  62  96  83  56  97  72  91 100  94  69  57  59  99]

# %%
#creation of transformer columns
num_cols=x.select_dtypes(exclude="object").columns
cat_cols=x.select_dtypes(include="object").columns


from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

num_trans=StandardScaler() 
oh_trans=OneHotEncoder()
preprocessor=ColumnTransformer(
    [
        ("OneHotEncoder",oh_trans,cat_cols),
        ("StandardScalar",num_trans,num_cols),
    ]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7508\369488542.py in ?()
#       1 #creation of transformer columns
# ----> 2 num_cols=x.select_dtypes(exclude="object").columns
#       3 cat_cols=x.select_dtypes(include="object").columns
#       4
#       5
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'select_dtypes'

# %%
# x=preprocessor.fit_transform(x)
